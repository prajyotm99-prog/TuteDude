# %%
prices = [100,250,400,1200,50]

# %%
def gst(num):
    return num * 1.18

# %%
print(f"before prices : {prices}")
print(f"after gst : {list(map(gst, prices))}")
# Out:
# before prices : [100, 250, 400, 1200, 50]
# after gst : [118.0, 295.0, 472.0, 1416.0, 59.0]
