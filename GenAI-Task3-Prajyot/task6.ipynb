# %%
prices = [100,250,400,1200,50,1500,2000,500]

# %%
discounted = list(map(lambda x: x * .9, prices))
filtered = list(filter(lambda x: x > 300, discounted))

# %%
print(f"discounted prices : {discounted} \nfiltered list : {filtered}")
# Out:
# discounted prices : [90.0, 225.0, 360.0, 1080.0, 45.0, 1350.0, 1800.0, 450.0]
# filtered list : [360.0, 1080.0, 1350.0, 1800.0, 450.0]
