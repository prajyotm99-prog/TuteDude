# %%
def apply_discount(price, discount = 5):
    if discount > 60:
        return price - (price * .60)
    return price - (price * discount / 100)

# %%
print(apply_discount(1000,10))
print(apply_discount(500))
print(apply_discount(1000,95))
# Out:
# 900.0
# 475.0
# 400.0
