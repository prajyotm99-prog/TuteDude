# %%
daily = [200,150,0,400,50,-1,300]
total_sales = []

# %%
for p in daily:
    if isinstance(p, (int, float)):
        if p == -1:
            break
        elif p == 0:
            continue
        else:
            total_sales.append(p)
print(sum(total_sales))
# Out:
# 800
