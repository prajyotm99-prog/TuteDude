# %% [markdown]
# # Task - 1

# %%
from Math_utils import sq
from string_utils import *

# %%
square = sq(5)
print(square)
print(sq(10))
# Out:
# 25
# 100

# %%
from Math_utils import *
sum  = add(5,1)
print(sum)
diff = subtract(1,10)
print(diff)
# Out:
# 6
# -9

# %% [markdown]
# # TASK - 2

# %%
from string_utils import *

# %%
print(cw("dog"))
# Out:
# DOG

# %%
rs("tools")
# Out:
# 'sloot'

# %%
cc("hi how are You")
# Out:
# 11

# %%
wc("hi how are you")
# Out:
# 4

# %% [markdown]
# # TASK - 3

# %%
from shop_package.discount import apply_discount

# %%
apply_discount(100,10)
# Out:
# 90.0

# %%
from shop_package.discount import flat_discount as fd

fd(100)
# Out:
# 50

# %%
from shop_package import apply_tax

# %%
apply_tax(1000)
# Out:
# 1100.0

# %%
from shop_package.billing import calculate_total

# %%
calculate_total([10,20,50,60])
# Out:
# 140

# %%
import shop_package.discount as disc

# %%
print(disc.apply_discount(500,10))
# Out:
# 450.0
