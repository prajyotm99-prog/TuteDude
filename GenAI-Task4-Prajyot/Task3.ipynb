# %%
new = [5000,2500, 1700]
with open('sales_data.txt', 'a') as f:
    for i in new:
        f.write(f"{i} \n")

# %%
with open('sales_data.txt', 'r') as f:
    content = f.read()
print(content)
# Out:
# 120
# 450
# 980
# 1500
# 3000
# 5000
# 2500
# 1700

# %%
with open('sales_data.txt', 'r') as f:
    total_lines = len(f.readlines())
print(f"total nu of lines : {total_lines}")
# Out:
# total nu of lines : 8
