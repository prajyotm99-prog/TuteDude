# %%
sales = [120,450,980,1500,3000]
with open("sales_data.txt", 'w') as f:
    for i in sales:
        f.write(f"{str(i)} \n")

# %%
f= open('sales_data.txt','r')
content = f.read()
print(content)
# Out:
# 120
# 450
# 980
# 1500
# 3000

# %%
sales = [120,450,980,1500,3000]
with open("sales_data.txt", 'w') as f:
    for i in sales:
        f.write(f"{str(i)} ,")
