# %%
product = ["apple", "banana", "cherry", "orange", "kiwi", "melon"]
sample_product = ("Apple", 150, "Fruit")

# %%
print(product[-2:])
# Out:
# ['kiwi', 'melon']

# %%
product.append("grape")
product.append("watermelon")
print(product)
# Out:
# ['apple', 'banana', 'cherry', 'orange', 'kiwi', 'melon', 'grape', 'watermelon', 'grape', 'watermelon']

# %%
sample_list = list(sample_product)
print(sample_list)
sample_list[1] = 200
print(sample_list)
# Out:
# ['Apple', 150, 'Fruit']
# ['Apple', 200, 'Fruit']

# %%
tuple_back = tuple(sample_list)
print(tuple_back)
# Out:
# ('Apple', 200, 'Fruit')
