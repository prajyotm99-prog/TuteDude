# %%
product = ["apple", "potato","trimmer","tv","icecream","laptop"]
category = ["fruit", "vegetable", "tool", "electronics", "dessert", "electronics"]

# %%
category_set = set(category)
print(category_set)
# Out:
# {'electronics', 'tool', 'fruit', 'dessert', 'vegetable'}

# %%
category_set.add("clothing")
category_set.add("fruit")
category_set.add("tool")
print(category_set)
# Out:
# {'electronics', 'clothing', 'tool', 'fruit', 'dessert', 'vegetable'}

# %%
if "fruit" in category_set:
     print(True)
else:
     print(False)
# Out:
# True

# %%
print(len(category_set))
# Out:
# 6
